# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame(
    {"a" : [4 ,5, 6],
    "b" : [7, 8, 9],
    "c" : [10, 11, 12]},
    index = [1, 2, 3])
df
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
df = pd.DataFrame(
    [[4, 7, 10],
    [5, 8, 11],
    [6, 9, 12]],
    index=[1, 2, 3],
    columns=['a', 'b', 'c'])
df
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
import numpy as np
df = pd.DataFrame(
    {"a" : [4 ,5, 6, 6, np.nan],
    "b" : [7, 8, 9, np.nan, 9],
    "c" : [10, 11, 12, 12,np.nan]})
df
# Out:
#      a    b     c
# 0  4.0  7.0  10.0
# 1  5.0  8.0  11.0
# 2  6.0  9.0  12.0
# 3  6.0  NaN  12.0
# 4  NaN  9.0   NaN

# %%
df[df['c'] > 7]
# Out:
#      a    b     c
# 0  4.0  7.0  10.0
# 1  5.0  8.0  11.0
# 2  6.0  9.0  12.0
# 3  6.0  NaN  12.0

# %%
df
# Out:
#      a    b     c
# 0  4.0  7.0  10.0
# 1  5.0  8.0  11.0
# 2  6.0  9.0  12.0
# 3  6.0  NaN  12.0
# 4  NaN  9.0   NaN

# %%
df.drop_duplicates() #중복행 없애주는값
# Out:
#      a    b     c
# 0  4.0  7.0  10.0
# 1  5.0  8.0  11.0
# 2  6.0  9.0  12.0
# 3  6.0  NaN  12.0
# 4  NaN  9.0   NaN

# %%
df[df["b"] != 7]
# Out:
#      a    b     c
# 1  5.0  8.0  11.0
# 2  6.0  9.0  12.0
# 3  6.0  NaN  12.0
# 4  NaN  9.0   NaN

# %%
df
# Out:
#      a    b     c
# 0  4.0  7.0  10.0
# 1  5.0  8.0  11.0
# 2  6.0  9.0  12.0
# 3  6.0  NaN  12.0
# 4  NaN  9.0   NaN

# %%
df.a.isin([5])
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# Name: a, dtype: bool

# %%
pd.isnull(df)
# Out:
#        a      b      c
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False   True  False
# 4   True  False   True

# %%
df['a'].isnull().sum()
# Out:
# 1

# %%
pd.notnull(df)
# Out:
#        a      b      c
# 0   True   True   True
# 1   True   True   True
# 2   True   True   True
# 3   True  False   True
# 4  False   True  False

# %%
df.notnull().sum()
# Out:
# a    4
# b    4
# c    4
# dtype: int64

# %%
df.a.notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# Name: a, dtype: bool

# %%
df
# Out:
#      a    b     c
# 0  4.0  7.0  10.0
# 1  5.0  8.0  11.0
# 2  6.0  9.0  12.0
# 3  6.0  NaN  12.0
# 4  NaN  9.0   NaN

# %%
df.sample(n = 2)
# Out:
#      a    b     c
# 3  6.0  NaN  12.0
# 1  5.0  8.0  11.0

# %%
df.iloc[ 1:]
# Out:
#      a    b     c
# 1  5.0  8.0  11.0
# 2  6.0  9.0  12.0
# 3  6.0  NaN  12.0
# 4  NaN  9.0   NaN

# %%
import seaborn as sns

# %%
df = sns.load_dataset("iris")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df[['sepal_width','sepal_length','species']]
# Out:
#      sepal_width  sepal_length    species
# 0            3.5           5.1     setosa
# 1            3.0           4.9     setosa
# 2            3.2           4.7     setosa
# 3            3.1           4.6     setosa
# 4            3.6           5.0     setosa
# ..           ...           ...        ...
# 145          3.0           6.7  virginica
# 146          2.5           6.3  virginica
# 147          3.0           6.5  virginica
# 148          3.4           6.2  virginica
# 149          3.0           5.9  virginica
#
# [150 rows x 3 columns]

# %%
df['sepal_width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
df.filter(regex='length')
# Out:
#      sepal_length  petal_length
# 0             5.1           1.4
# 1             4.9           1.4
# 2             4.7           1.3
# 3             4.6           1.5
# 4             5.0           1.4
# ..            ...           ...
# 145           6.7           5.2
# 146           6.3           5.0
# 147           6.5           5.2
# 148           6.2           5.4
# 149           5.9           5.1
#
# [150 rows x 2 columns]

# %%
df.loc[2:5, 'sepal_width':'petal_width']
# Out:
#    sepal_width  petal_length  petal_width
# 2          3.2           1.3          0.2
# 3          3.1           1.5          0.2
# 4          3.6           1.4          0.2
# 5          3.9           1.7          0.4

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.loc[df['sepal_length'] > 5, ['sepal_length','sepal_width']]
# Out:
#      sepal_length  sepal_width
# 0             5.1          3.5
# 5             5.4          3.9
# 10            5.4          3.7
# 14            5.8          4.0
# 15            5.7          4.4
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [118 rows x 2 columns]

# %%
pd.DataFrame(df['species'].value_counts())
# Out:
#             species
# versicolor       50
# setosa           50
# virginica        50

# %%
len(df)
# Out:
# 150

# %%
df.shape
# Out:
# (150, 5)

# %%
df.describe()
df.describe(include= 'all')
# Out:
#         sepal_length  sepal_width  petal_length  petal_width     species
# count     150.000000   150.000000    150.000000   150.000000         150
# unique           NaN          NaN           NaN          NaN           3
# top              NaN          NaN           NaN          NaN  versicolor
# freq             NaN          NaN           NaN          NaN          50
# mean        5.843333     3.057333      3.758000     1.199333         NaN
# std         0.828066     0.435866      1.765298     0.762238         NaN
# min         4.300000     2.000000      1.000000     0.100000         NaN
# 25%         5.100000     2.800000      1.600000     0.300000         NaN
# 50%         5.800000     3.000000      4.350000     1.300000         NaN
# 75%         6.400000     3.300000      5.100000     1.800000         NaN
# max         7.900000     4.400000      6.900000     2.500000         NaN

# %%
df.describe(include= [np.object])
df.describe(include= [np.number])
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# sum()
# Sum values of each object.
# count()
# Count non-NA/null values of
# each object.
# median()
# Median value of each object.
# quantile([0.25,0.75])
# Quantiles of each object.
# apply(function)
# Apply function to each object.
# min()
# Minimum value in each object.
# max()
# Maximum value in each object.
# mean()
# Mean value of each object.
# var()
# Variance of each object.
# std()
# Standard deviation of each
# object.

# %%
df['petal_width'].count()
# Out:
# 150

# %%
df['petal_width'].mean()
# Out:
# 1.199333333333334

# %%
df['petal_width'].median()
# Out:
# 1.3

# %%
df.min()
# Out:
# sepal_length       4.3
# sepal_width          2
# petal_length         1
# petal_width        0.1
# species         setosa
# dtype: object

# %%
df.max()
# Out:
# sepal_length          7.9
# sepal_width           4.4
# petal_length          6.9
# petal_width           2.5
# species         virginica
# dtype: object

# %%
df.std()
# Out:
# sepal_length    0.828066
# sepal_width     0.435866
# petal_length    1.765298
# petal_width     0.762238
# dtype: float64

# %% [markdown]
# ## apply(function)

# %%
df.apply(lambda x : x[2])
# Out:
# sepal_length       4.7
# sepal_width        3.2
# petal_length       1.3
# petal_width        0.2
# species         setosa
# dtype: object

# %%
def smp(x):
    # 뒤에서 3번째 까지의 문자를 가져오는 함수
    x = x[-3]
    return x

# %%
df = pd.DataFrame([])

# %%
df.dropna?

# %%
df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman'],
                   "toy": [np.nan, 'Batmobile', 'Bullwhip'],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"),
                        pd.NaT]})
df
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna(axis = 1, how = 'all') #전부다 na일때 드랍시킨다.
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna(axis = 1, how = 'any') #하나라도 있으면
# Out:
#        name
# 0    Alfred
# 1    Batman
# 2  Catwoman

# %%
df.dropna(axis = 0, how = 'any')
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
df.fillna(0)
# Out:
#        name        toy                 born
# 0    Alfred          0                    0
# 1    Batman  Batmobile  1940-04-25 00:00:00
# 2  Catwoman   Bullwhip                    0

# %%
df['born'].max()
# Out:
# Timestamp('1940-04-25 00:00:00')

# %%
df.isnull().sum()
# Out:
# name    0
# toy     1
# born    2
# dtype: int64

# %%
df = pd.DataFrame({
    'A' : range(1,11),
    'B' : np.random.randn(10)
})
df
# Out:
#     A         B
# 0   1  0.886914
# 1   2  0.598670
# 2   3  1.408800
# 3   4  1.783437
# 4   5 -1.479593
# 5   6  2.024729
# 6   7 -0.493569
# 7   8  0.737382
# 8   9 -1.172243
# 9  10 -0.569248

# %%
df.assign(ln_A = lambda x:np.log(x.A)).head()
# Out:
#    A         B      ln_A
# 0  1  0.886914  0.000000
# 1  2  0.598670  0.693147
# 2  3  1.408800  1.098612
# 3  4  1.783437  1.386294
# 4  5 -1.479593  1.609438

# %%
df["ln_A"] =  np.log(df.A)
df
# Out:
#     A         B      ln_A
# 0   1  0.886914  0.000000
# 1   2  0.598670  0.693147
# 2   3  1.408800  1.098612
# 3   4  1.783437  1.386294
# 4   5 -1.479593  1.609438
# 5   6  2.024729  1.791759
# 6   7 -0.493569  1.945910
# 7   8  0.737382  2.079442
# 8   9 -1.172243  2.197225
# 9  10 -0.569248  2.302585

# %%
df.max(axis = 1)
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     4.0
# 4     5.0
# 5     6.0
# 6     7.0
# 7     8.0
# 8     9.0
# 9    10.0
# dtype: float64

# %%
df["A"].clip(lower = 2, upper=3)
# Out:
# 0    2
# 1    2
# 2    3
# 3    3
# 4    3
# 5    3
# 6    3
# 7    3
# 8    3
# 9    3
# Name: A, dtype: int64

# %%
df["B"].abs() #절대값
# Out:
# 0    0.886914
# 1    0.598670
# 2    1.408800
# 3    1.783437
# 4    1.479593
# 5    2.024729
# 6    0.493569
# 7    0.737382
# 8    1.172243
# 9    0.569248
# Name: B, dtype: float64

# %%
import seaborn as sns

# %%
df = sns.load_dataset("mpg")
df.shape
# Out:
# (398, 9)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.sort_values('cylinders')
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 111  18.0          3          70.0        90.0    2124          13.5
# 71   19.0          3          70.0        97.0    2330          13.5
# 334  23.7          3          70.0       100.0    2420          12.5
# 243  21.5          3          80.0       110.0    2720          13.5
# 267  27.5          4         134.0        95.0    2560          14.2
# ..    ...        ...           ...         ...     ...           ...
# 86   14.0          8         304.0       150.0    3672          11.5
# 285  17.0          8         305.0       130.0    3840          15.4
# 286  17.6          8         302.0       129.0    3725          13.4
# 92   13.0          8         351.0       158.0    4363          13.0
# 0    18.0          8         307.0       130.0    3504          12.0
#
#      model_year origin                       name
# 111          73  japan                  maxda rx3
# 71           72  japan            mazda rx2 coupe
# 334          80  japan              mazda rx-7 gs
# 243          77  japan                 mazda rx-4
# 267          78  japan              toyota corona
# ..          ...    ...                        ...
# 86           73    usa                amc matador
# 285          79    usa  chevrolet caprice classic
# 286          79    usa            ford ltd landau
# 92           73    usa                   ford ltd
# 0            70    usa  chevrolet chevelle malibu
#
# [398 rows x 9 columns]

# %%
df.sort_values('mpg',ascending = False).head()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 322  46.6          4          86.0        65.0    2110          17.9
# 329  44.6          4          91.0        67.0    1850          13.8
# 325  44.3          4          90.0        48.0    2085          21.7
# 394  44.0          4          97.0        52.0    2130          24.6
# 326  43.4          4          90.0        48.0    2335          23.7
#
#      model_year  origin                  name
# 322          80   japan             mazda glc
# 329          80   japan   honda civic 1500 gl
# 325          80  europe  vw rabbit c (diesel)
# 394          82  europe             vw pickup
# 326          80  europe    vw dasher (diesel)

# %%
df = df.rename(columns = {'model_year':'year'})

# %%
df.sort_index()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 393  27.0          4         140.0        86.0    2790          15.6    82
# 394  44.0          4          97.0        52.0    2130          24.6    82
# 395  32.0          4         135.0        84.0    2295          11.6    82
# 396  28.0          4         120.0        79.0    2625          18.6    82
# 397  31.0          4         119.0        82.0    2720          19.4    82
#
#      origin                       name
# 0       usa  chevrolet chevelle malibu
# 1       usa          buick skylark 320
# 2       usa         plymouth satellite
# 3       usa              amc rebel sst
# 4       usa                ford torino
# ..      ...                        ...
# 393     usa            ford mustang gl
# 394  europe                  vw pickup
# 395     usa              dodge rampage
# 396     usa                ford ranger
# 397     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %%
df.reset_index()
# Out:
#      index   mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0        0  18.0          8         307.0       130.0    3504          12.0
# 1        1  15.0          8         350.0       165.0    3693          11.5
# 2        2  18.0          8         318.0       150.0    3436          11.0
# 3        3  16.0          8         304.0       150.0    3433          12.0
# 4        4  17.0          8         302.0       140.0    3449          10.5
# ..     ...   ...        ...           ...         ...     ...           ...
# 393    393  27.0          4         140.0        86.0    2790          15.6
# 394    394  44.0          4          97.0        52.0    2130          24.6
# 395    395  32.0          4         135.0        84.0    2295          11.6
# 396    396  28.0          4         120.0        79.0    2625          18.6
# 397    397  31.0          4         119.0        82.0    2720          19.4
#
#      year  origin                       name
# 0      70     usa  chevrolet chevelle malibu
# 1      70     usa          buick skylark 320
# 2      70     usa         plymouth satellite
# 3      70     usa              amc rebel sst
# 4      70     usa                ford torino
# ..    ...     ...                        ...
# 393    82     usa            ford mustang gl
# 394    82  europe                  vw pickup
# 395    82     usa              dodge rampage
# 396    82     usa                ford ranger
# 397    82     usa                 chevy s-10
#
# [398 rows x 10 columns]

# %%
df.drop(columns = ['mpg','year'])
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  origin  \
# 0            8         307.0       130.0    3504          12.0     usa
# 1            8         350.0       165.0    3693          11.5     usa
# 2            8         318.0       150.0    3436          11.0     usa
# 3            8         304.0       150.0    3433          12.0     usa
# 4            8         302.0       140.0    3449          10.5     usa
# ..         ...           ...         ...     ...           ...     ...
# 393          4         140.0        86.0    2790          15.6     usa
# 394          4          97.0        52.0    2130          24.6  europe
# 395          4         135.0        84.0    2295          11.6     usa
# 396          4         120.0        79.0    2625          18.6     usa
# 397          4         119.0        82.0    2720          19.4     usa
#
#                           name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# ..                         ...
# 393            ford mustang gl
# 394                  vw pickup
# 395              dodge rampage
# 396                ford ranger
# 397                 chevy s-10
#
# [398 rows x 7 columns]

# %%
pd.melt?

# %%
 df = pd.DataFrame({'A': {0: 'a', 1: 'b', 2: 'c'},
                    'B': {0: 1, 1: 3, 2: 5},
                    'C': {0: 2, 1: 4, 2: 6}})
    
df
# Out:
#    A  B  C
# 0  a  1  2
# 1  b  3  4
# 2  c  5  6

# %%
pd.melt(df, id_vars = ['A'], value_vars = ['B','C'])
# Out:
#    A variable  value
# 0  a        B      1
# 1  b        B      3
# 2  c        B      5
# 3  a        C      2
# 4  b        C      4
# 5  c        C      6

# %%
pd.melt(df, value_vars = ['A','B','C']).rename(columns = {
'variable' : 'var',
'value' : 'val'})
# Out:
#   var val
# 0   A   a
# 1   A   b
# 2   A   c
# 3   B   1
# 4   B   3
# 5   B   5
# 6   C   2
# 7   C   4
# 8   C   6

# %%
df.pivot?

# %%
df2 = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two','two'],
                    'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
                    'baz': [1, 2, 3, 4, 5, 6],
                    'zoo': ['x', 'y', 'z', 'q', 'w', 't']})
df2
# Out:
#    foo bar  baz zoo
# 0  one   A    1   x
# 1  one   B    2   y
# 2  one   C    3   z
# 3  two   A    4   q
# 4  two   B    5   w
# 5  two   C    6   t

# %%
df3 = df2.pivot(index = 'foo', columns = 'bar', values = 'baz' ).reset_index()
df3
# Out:
# bar  foo  A  B  C
# 0    one  1  2  3
# 1    two  4  5  6

# %%
df3.melt?

# %%
df3.melt(
    id_vars=['foo'], value_vars=['A','B','C']).sort_values(['foo','bar']).rename(columns = {'value' : 'baz'})
# Out:
#    foo bar  baz
# 0  one   A    1
# 2  one   B    2
# 4  one   C    3
# 1  two   A    4
# 3  two   B    5
# 5  two   C    6

# %%
pd.concat?

# %%
s1 = pd.Series(['a', 'b'])
s1
# Out:
# 0    a
# 1    b
# dtype: object

# %%
s2 = pd.Series(['c', 'd'])
s2
# Out:
# 0    c
# 1    d
# dtype: object

# %%
pd.concat([s1, s2],ignore_index=True)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
pd.concat([s1, s2], keys = ['s1','s2'], names=['Series name', 'Row ID'])
# Out:
# Series name  Row ID
# s1           0         a
#              1         b
# s2           0         c
#              1         d
# dtype: object

# %%
df1 = pd.DataFrame([['a', 1], ['b', 2]],
                   columns=['letter', 'number'])

df1
# Out:
#   letter  number
# 0      a       1
# 1      b       2

# %%
df2 = pd.DataFrame([['c', 3], ['d', 4]],
                   columns=['letter', 'number'])
df2
# Out:
#   letter  number
# 0      c       3
# 1      d       4

# %%
pd.concat([df1, df2], ignore_index = True)
# Out:
#   letter  number
# 0      a       1
# 1      b       2
# 2      c       3
# 3      d       4

# %%
df3 = pd.DataFrame([['c', 3, 'cat'], ['d', 4, 'dog']],
                   columns=['letter', 'number', 'animal'])
df3
# Out:
#   letter  number animal
# 0      c       3    cat
# 1      d       4    dog

# %%
pd.concat([df1, df3], join = "inner")
# Out:
#   letter  number
# 0      a       1
# 1      b       2
# 0      c       3
# 1      d       4

# %%
df4 = pd.DataFrame([['bird', 'polly'], ['monkey', 'george']],
                   columns=['animal', 'name'])
df4
# Out:
#    animal    name
# 0    bird   polly
# 1  monkey  george

# %%
df5 = pd.DataFrame([1], index=['a'])
df5
# Out:
#    0
# a  1

# %%
df6 = pd.DataFrame([2], index=['a'])
df6
# Out:
#    0
# a  2

# %%
adf = pd.DataFrame({"x1": ["A","B","C"], "x2" : [1,2,3]})
adf
# Out:
#   x1  x2
# 0  A   1
# 1  B   2
# 2  C   3

# %%
bdf = pd.DataFrame({"x1": ["A","B","D"], "x3" : ["T","F","T"]})
bdf
# Out:
#   x1 x3
# 0  A  T
# 1  B  F
# 2  D  T

# %%
pd.merge(adf, bdf, how='left', on='x1')
# Out:
#   x1  x2   x3
# 0  A   1    T
# 1  B   2    F
# 2  C   3  NaN

# %%
pd.merge(adf, bdf, how='right', on='x1')
# Out:
#   x1   x2 x3
# 0  A  1.0  T
# 1  B  2.0  F
# 2  D  NaN  T

# %%
pd.merge(adf, bdf, how='inner', on='x1')
# Out:
#   x1  x2 x3
# 0  A   1  T
# 1  B   2  F

# %%
pd.merge(adf, bdf, how='outer', on='x1')
# Out:
#   x1   x2   x3
# 0  A  1.0    T
# 1  B  2.0    F
# 2  C  3.0  NaN
# 3  D  NaN    T

# %%
adf[adf.x1.isin(bdf.x1)]
# Out:
#   x1  x2
# 0  A   1
# 1  B   2

# %%
adf[~adf.x1.isin(bdf.x1)]
# Out:
#   x1  x2
# 2  C   3

# %%
ydf = pd.DataFrame({"x1": ["A","B","C"], "x2" : [1,2,3]})
ydf
# Out:
#   x1  x2
# 0  A   1
# 1  B   2
# 2  C   3

# %%
zdf = pd.DataFrame({"x1": ["B","C","D"], "x2" : [2,3,4]})
zdf
# Out:
#   x1  x2
# 0  B   2
# 1  C   3
# 2  D   4

# %%
pd.merge(ydf,zdf, how="outer")
# Out:
#   x1  x2
# 0  A   1
# 1  B   2
# 2  C   3
# 3  D   4

# %%
df = sns.load_dataset("mpg")
df.head(3)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite

# %%
df.groupby(by = "origin")["cylinders"].size()
# Out:
# origin
# europe     70
# japan      79
# usa       249
# Name: cylinders, dtype: int64

# %%
pd.DataFrame(df.groupby(["model_year","origin"])["cylinders"].mean())
# Out:
#                    cylinders
# model_year origin
# 70         europe   4.000000
#            japan    4.000000
#            usa      7.636364
# 71         europe   4.000000
#            japan    4.000000
#            usa      6.200000
# 72         europe   4.000000
#            japan    3.800000
#            usa      6.888889
# 73         europe   4.000000
#            japan    4.250000
#            usa      7.241379
# 74         europe   4.000000
#            japan    4.000000
#            usa      6.266667
# 75         europe   4.000000
#            japan    4.000000
#            usa      6.400000
# 76         europe   4.250000
#            japan    4.500000
#            usa      6.363636
# 77         europe   4.000000
#            japan    4.166667
#            usa      6.222222
# 78         europe   4.833333
#            japan    4.000000
#            usa      6.000000
# 79         europe   4.250000
#            japan    4.000000
#            usa      6.260870
# 80         europe   4.111111
#            japan    4.076923
#            usa      4.285714
# 81         europe   4.500000
#            japan    4.333333
#            usa      4.923077
# 82         europe   4.000000
#            japan    4.000000
#            usa      4.300000

# %%
df2 = pd.DataFrame(
[[4, 7, 10],
[5, 8, 11],
[6, 9, 12]],
index=[1, 2, 3],
columns=['a', 'b', 'c'])

# %%
df2
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
df["model_year"].rank(pct = True)
# Out:
# 0      0.037688
# 1      0.037688
# 2      0.037688
# 3      0.037688
# 4      0.037688
#          ...
# 393    0.962312
# 394    0.962312
# 395    0.962312
# 396    0.962312
# 397    0.962312
# Name: model_year, Length: 398, dtype: float64

# %%
df2
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
df2.cumsum()
# Out:
#     a   b   c
# 1   4   7  10
# 2   9  15  21
# 3  15  24  33

# %%
s = pd.Series(np.random.randn(1000),
         index = pd.date_range('1/1/2015', periods = 1000))

# %%
s= s.cumsum()
s.plot()

# %%
r= s.rolling(window = 60)
r.mean()
# Out:
# 2015-01-01          NaN
# 2015-01-02          NaN
# 2015-01-03          NaN
# 2015-01-04          NaN
# 2015-01-05          NaN
#                 ...
# 2017-09-22   -12.010863
# 2017-09-23   -12.027393
# 2017-09-24   -12.042461
# 2017-09-25   -12.101758
# 2017-09-26   -12.207151
# Freq: D, Length: 1000, dtype: float64

# %%
df = pd.DataFrame

# %%
df.plot?

# %%
ts = pd.Series(np.random.randn(1000),
         index = pd.date_range('1/1/2000', periods = 1000))

# %%
ts
# Out:
# 2000-01-01    1.040433
# 2000-01-02   -0.669550
# 2000-01-03    0.376226
# 2000-01-04   -0.609863
# 2000-01-05    0.579124
#                 ...
# 2002-09-22    0.501479
# 2002-09-23    0.885255
# 2002-09-24   -0.940062
# 2002-09-25    0.397744
# 2002-09-26    1.184016
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()

# %%
ts = ts.cumsum()
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4),
         index = ts.index, columns = list('ABCD'))

# %%
df.plot()

# %%
df = df.cumsum()
df.plot()

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2),
                   columns = ['B','C']).cumsum()

# %%
df3
# Out:
#              B         C
# 0    -0.060678 -0.473920
# 1     0.668854 -0.279908
# 2     0.444066  0.799766
# 3     0.327715  0.974065
# 4     0.951124 -0.205388
# ..         ...       ...
# 995 -71.215233 -3.085190
# 996 -71.130307 -3.452072
# 997 -71.338036 -3.403992
# 998 -70.386280 -3.856295
# 999 -70.637232 -3.956196
#
# [1000 rows x 2 columns]

# %%
df = pd.DataFrame(np.random.randn(1000, 4),
                   index = ts.index, columns = list('ABCD'))

# %%
df.head(6)
# Out:
#                    A         B         C         D
# 2000-01-01  0.208389  1.440971  0.167352  1.859917
# 2000-01-02 -0.385750 -0.805847 -0.919114  0.439745
# 2000-01-03  1.005151 -1.342176 -0.146284 -1.107972
# 2000-01-04  0.158081 -0.923828  0.874254 -0.222271
# 2000-01-05 -0.234517 -1.191601 -0.729756 -1.130567
# 2000-01-06  0.016169  0.165504  0.063527 -0.050312

# %%
df.tail(2)
# Out:
#                    A         B         C         D
# 2002-09-25  0.255364  3.114731  1.013104  0.526763
# 2002-09-26 -0.928906 -1.154082 -0.927445  1.545100

# %%
df.iloc[5].plot(kind = 'bar')

# %%
df.iloc[5].plot.bar()
plt.axhline(0,color = 'k')

# %%
df2 = pd.DataFrame(np.random.randn(10,4), columns = ['a','b','c','d'])
df2
# Out:
#           a         b         c         d
# 0  0.755020  1.240886 -0.742011 -0.176721
# 1  0.617034 -1.009245 -0.385247  0.594547
# 2  0.120303 -1.437358 -0.621796  0.044585
# 3 -0.308644  0.015534 -0.362011 -0.120724
# 4 -0.919280  0.244386 -1.180725 -0.431588
# 5  0.344407  0.291289 -1.223434  0.755900
# 6 -0.154402  1.065960  0.046282  0.011647
# 7 -0.400065 -0.623553 -0.114313  0.824036
# 8 -0.418512 -0.188345  1.947652  2.342204
# 9 -1.149543  0.478645  0.122665  0.474560
